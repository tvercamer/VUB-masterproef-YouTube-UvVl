# %% [markdown]
# # Data Collectie
#
# In deze notebook wordt alle nodige data verzameld om de verdere analyses te kunnen uitvoeren.<br>
# Elk van de analyses vindt plaats in een aparte notebook.b

# %% [markdown]
# ## Stap 1: Klaarzetten van de notebook.
#
# In deze stap worden alle nodige libraries ingeladen en klaargezet.<br>
# Dit vereenvoudigt het verdere verloop van de notebook.

# %%
# Importeer standaard libraries
import importlib
import numpy as np
from dotenv import load_dotenv

# %%
# Importeer .env variables
load_dotenv()
# Out:
# True

# %%
# Importeer zelfgeschreven libraries
from lib import youtube, helpers

# Automatisch herladen van libraries bij aanpassingen
importlib.reload(youtube)
importlib.reload(helpers);

# %% [markdown]
# ## Stap 2: Ophalen van de data.
#
# In deze stap wordt gebruik gemaakt van de YouTube APIs (Data en Analytics) om de nodige data op te halen.<br>
# Deze data wordt vervolgens in een pandas dataframe geplaatst om verder te bewerken.<br>
# Verder wordt de data ook manueel geannoteerd, conform de methodologie van de masterproef.<br>
# Uiteindelijk wordt iedere dataset opgeslagen in een apart Excel-bestand, zodat dit in de volgende stappen kan worden ingeladen.

# %% [markdown]
# ### 2.1 Video Data

# %%
# Definieer de lijst van geselecteerde video's.
# Gebruik hierbij de video_id (deel van de URL) van de video's die je wil analyseren.
video_ids = np.array(['GYtUhykvOos','PkmUT16Um_0','JxWT-zYtcGg','rJbiY3S69ek','ewUjvz3nDj4','BDq4yJCRFcE','ih7RQ5lFwIY','Wm-Yk5bK_fk','4efyusOrx14','PUztndRNSU8','1QsVq3vlZsk'])

# %%
# Gebruik de YouTube Data API om generieke informatie op te halen over de video.
# Dit is data zoals: title, publish_date, metrics op het moment van ophalen ...
generic_data = youtube.get_generic_info(video_ids)

# %%
# Gebruik de YouTube Analytics API om metrics op te halen over verschillende tijdsintervallen heen.
# De tijdsintervallen zijn steeds gerekend vanaf de publicatie van de video.
# De tijdsintervallen zijn: 24, 1w, 2w, 1m, 2m, 3m (meer is niet mogelijk, gezien de duur van de masterproef)
metrics = youtube.get_metrics_over_time(generic_data)

# %%
# Voeg de data van generic_data en metrics samen in één dataframe.
videos = generic_data.merge(metrics, how='inner', on='id').set_index('id')

# Publish_date_x en publish_date_y zijn dubbele kolommen, verwijder één van beide en hernoem de andere.
videos.drop(columns=['publish_date_y'], inplace=True)
videos.rename(columns={'publish_date_x': 'publish_date'}, inplace=True)

# %%
# Voeg manuele annotaties toe aan de data.
# Deze annotaties zijn nodig om de analyses correct te kunnen uitvoeren.
videos['has_CTA'] = np.array([False, True, True, False, True, True, False, False, True, False, True])
videos['is_beta'] = np.array([None, False, False, None, True, True, None, None, False, None, True])
videos['university'] = np.array(['KUL', 'VUB', 'UA', 'VUB', 'UG', 'UG', 'UA', 'UG', 'VUB', 'UG', 'UA'])
videos['gender'] = np.array([0, 0, 0, 0, 1, 0, 1, 1, 0, 0, 1]) # F=0, M=1
videos['has_ambassador'] = np.array([True, True, False, False, False, False, False, False, False, False, False])

# %%
# Toon de dataframe videos
videos
# Out:
#                                                          title  \
# id
# GYtUhykvOos  Is het erg als tieners bijna nooit met vriende...
# PkmUT16Um_0  Hoe kan je helpen als je buur ernstig ziek is?...
# JxWT-zYtcGg  Hoe zorgt Trump ervoor dat we minder eenzaam z...
# rJbiY3S69ek  Hoe kan je tijdens een superleuke vakantie toc...
# ewUjvz3nDj4           Waarom is een vlam niet vierkant? #dww24
# BDq4yJCRFcE                          Waarom bestaat de winter?
# ih7RQ5lFwIY     Waarom spelen bandjes op kerstmarkten zo vals?
# Wm-Yk5bK_fk          Waarom is eten met een korstje lekkerder?
# 4efyusOrx14         Helpt zebradrinken tegen een kater? #dww24
# PUztndRNSU8  Is het een goed idee om te trouwen met je best...
# 1QsVq3vlZsk      Waarom vriezen vissen niet vast in de winter?
#
#                      publish_date duration  views  likes  dislikes  comments  \
# id
# GYtUhykvOos  2024-12-01T07:00:09Z    10:59   4127     99         2        13
# PkmUT16Um_0  2024-12-08T09:00:27Z    16:15   1953     36         0         3
# JxWT-zYtcGg  2024-12-10T06:00:16Z    17:01   2120     40         5         2
# rJbiY3S69ek  2024-12-15T09:00:48Z    16:27   1136     23         1         1
# ewUjvz3nDj4  2024-12-17T09:00:40Z    16:46   2023     45         2         4
# BDq4yJCRFcE  2024-12-22T08:00:08Z    10:03   2005     52         0         9
# ih7RQ5lFwIY  2024-12-24T08:00:38Z    12:00   5949    108         0        10
# Wm-Yk5bK_fk  2024-12-29T09:00:28Z    12:48   1853     48         0         1
# 4efyusOrx14  2024-12-31T09:00:04Z    13:15   2760     67         3         6
# PUztndRNSU8  2025-01-05T09:00:22Z    14:44   4218    104         0         4
# 1QsVq3vlZsk  2025-01-19T09:00:02Z     9:32   3120     77         0         5
#
#              views_24h  views_1w  views_2w  ...  comments_1w  comments_2w  \
# id                                          ...
# GYtUhykvOos       1860      2682      3080  ...            3            4
# PkmUT16Um_0        851      1277      1417  ...            3            3
# JxWT-zYtcGg        831      1415      1575  ...            2            2
# rJbiY3S69ek        560       763       855  ...            6            6
# ewUjvz3nDj4        750      1460      1652  ...            4            5
# BDq4yJCRFcE       1103      1461      1625  ...            6            6
# ih7RQ5lFwIY       1534      5299      5696  ...            7            7
# Wm-Yk5bK_fk       1003      1428      1584  ...            2            2
# 4efyusOrx14       1086      2068      2313  ...            3            3
# PUztndRNSU8       1605      2961      3409  ...            2            3
# 1QsVq3vlZsk       1506      2304      2716  ...            4            5
#
#              comments_1m  comments_2m  comments_3m  has_CTA  is_beta  \
# id
# GYtUhykvOos            4          4.0          4.0    False     None
# PkmUT16Um_0            3          3.0          3.0     True    False
# JxWT-zYtcGg            2          2.0          2.0     True    False
# rJbiY3S69ek            6          6.0          NaN    False     None
# ewUjvz3nDj4            5          5.0          NaN     True     True
# BDq4yJCRFcE            6          6.0          NaN     True     True
# ih7RQ5lFwIY            7          7.0          NaN    False     None
# Wm-Yk5bK_fk            2          2.0          NaN    False     None
# 4efyusOrx14            3          4.0          NaN     True    False
# PUztndRNSU8            3          3.0          NaN    False     None
# 1QsVq3vlZsk            5          NaN          NaN     True     True
#
#              university  gender  has_ambassador
# id
# GYtUhykvOos         KUL       0            True
# PkmUT16Um_0         VUB       0            True
# JxWT-zYtcGg          UA       0           False
# rJbiY3S69ek         VUB       0           False
# ewUjvz3nDj4          UG       1           False
# BDq4yJCRFcE          UG       0           False
# ih7RQ5lFwIY          UA       1           False
# Wm-Yk5bK_fk          UG       1           False
# 4efyusOrx14         VUB       0           False
# PUztndRNSU8          UG       0           False
# 1QsVq3vlZsk          UA       1           False
#
# [11 rows x 36 columns]

# %%
# Sla de data op in een Excel bestand
videos.to_excel('../output/videos.xlsx')

# %% [markdown]
# ### 2.2 Comments Data

# %%
# Maak gebruik van de videos dataframe om de comments op te halen.
comments = youtube.get_video_comments(videos)

# %%
# In de comments staan persoonsnamen, deze worden verwijderd om privacy te garanderen.
# De handler voor de Universiteit van Vlaanderen wordt wel behouden.
comments = helpers.anonymize_comments(comments)

# %%
# De comments zijn NL, maar gezien de beperkte hoeveelheid data, is het niet mogelijk om een model te trainen.
# Daarom werd gekozen om de comments te vertalen naar het Engels m.b.v. Google Translate.
# Deze vertaalde comments kunnen daarna verder opgenomen worden in een sentiment analyse met VADER.
comments_nl = comments['comment_nl'].tolist()
comments_en = [helpers.translate_to_english(comment) for comment in comments_nl]
comments['comment_en'] = comments_en

# %%
# Toon de dataframe comments
comments.head()
# Out:
#             id                                         comment_id  \
# 0  GYtUhykvOos                         UgwgDxZ0r0BFkJLKYP14AaABAg
# 1  GYtUhykvOos                         UgwC9fuK93PSKktjkxh4AaABAg
# 2  GYtUhykvOos  UgwC9fuK93PSKktjkxh4AaABAg.ABu0SmM1ulIABwrojaD6Sm
# 3  GYtUhykvOos                         UgzokIGytUWEUq-xNDZ4AaABAg
# 4  GYtUhykvOos  UgzokIGytUWEUq-xNDZ4AaABAg.ABmfTAkhK-jABws0aLr-Mi
#
#             parent_comment_id                      author  \
# 0                        None  @UniversiteitvanVlaanderen
# 1                        None                       User1
# 2  UgwC9fuK93PSKktjkxh4AaABAg  @UniversiteitvanVlaanderen
# 3                        None                       User2
# 4  UgzokIGytUWEUq-xNDZ4AaABAg  @UniversiteitvanVlaanderen
#
#            published_at  like_count  \
# 0  2024-12-01T08:59:16Z           2
# 1  2024-12-11T07:33:10Z           2
# 2  2024-12-12T10:06:38Z           0
# 3  2024-12-08T11:06:17Z           3
# 4  2024-12-12T10:08:23Z           2
#
#                                           comment_nl  is_reply  \
# 0  Voel jij je ook soms eenzaam? Of ben wel vaak ...     False
# 1  ik heb ook een verhaal. mijn eenzaamheid is ni...     False
# 2  Wat een mooi en ook warm verhaal. Dankjewel da...      True
# 3  Er zijn dus jongeren die zich niet gelukkig vo...     False
# 4  Dat is zeker iets wat we ook nog eens aan een ...      True
#
#                                           comment_en
# 0  Do you sometimes feel lonely? Or am often not ...
# 1  I also have a story. My loneliness is not that...
# 2  What a beautiful and also warm story. Thank yo...
# 3  So there are young people who don't feel happy...
# 4  That is certainly something we also have to as...

# %%
# Sla de data op in een Excel bestand
comments.to_excel('../output/comments.xlsx')
